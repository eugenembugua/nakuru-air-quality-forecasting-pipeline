# %%
#Importing the dependencies
import json
from openaq import OpenAQ
import pandas as pd

# %%
#Read the secrets file
with open(r"../secrets.json", "r") as f:
    secrets = json.load(f)

# %%
#Grab the 'openaq-api-key' from secrets file
openaq_key = secrets.get("openaq-api-key")

if not openaq_key:
    raise ValueError("OpenAQ API key not found in secrets.json")

# %%
#Connect to the OpenAQ API using the key from secrets
client = OpenAQ(api_key=openaq_key)
client

# %%
#Queries OpenAQ for monitoring locations around Nairobi
bbox_locations_search = client.locations.list(
    bbox=(35.782471,-1.988126,39.924316,0.834931),
    limit=1000
)
bbox_locations_search.meta
# Out:
# Meta(name='openaq-api', website='/', page=1, limit=1000, found=13)

# %%
#Actual locations data
bbox_locations_search.results
# Out:
# [Location(id=5994, name='Nairobi CBD', locality=None, timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=120, name='AirNow Kenya'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=16244, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=16243, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=-1.28156, longitude=36.81883), bounds=[36.81883, -1.28156, 36.81883, -1.28156], distance=None, datetime_first=Datetime(utc='2018-04-23T00:00:00Z', local='2018-04-23T03:00:00+03:00'), datetime_last=Datetime(utc='2018-09-13T21:00:00Z', local='2018-09-14T00:00:00+03:00')),
#  Location(id=6317, name='Alliance Girls High', locality=None, timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=120, name='AirNow Kenya'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=17575, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=17576, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=-1.26614, longitude=36.66314), bounds=[36.66314, -1.26614, 36.66314, -1.26614], distance=None, datetime_first=Datetime(utc='2018-04-21T00:00:00Z', local='2018-04-21T03:00:00+03:00'), datetime_last=Datetime(utc='2018-11-20T23:00:00Z', local='2018-11-21T02:00:00+03:00')),
#  Location(id=352507, name='Nairobi RR', locality='N/A', timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=2002532, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=-1.23437, longitude=36.81732), bounds=[36.81732, -1.23437, 36.81732, -1.23437], distance=None, datetime_first=Datetime(utc='2022-06-16T17:00:00Z', local='2022-06-16T20:00:00+03:00'), datetime_last=Datetime(utc='2025-02-12T15:00:00Z', local='2025-02-12T18:00:00+03:00')),
#  Location(id=1894637, name='Nakuru', locality=None, timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=9, name='Clarity'), provider=ProviderBase(id=166, name='Clarity'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=4, name='Clarity Sensor')], sensors=[SensorBase(id=7466383, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7466384, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7466385, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7466386, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7466387, name='temperature f', parameter=ParameterBase(id=128, name='temperature', units='f', display_name='Temperature (F)'))], coordinates=Coordinates(latitude=-0.2674, longitude=36.0218), bounds=[36.0218, -0.2674, 36.0218, -0.2674], distance=None, datetime_first=Datetime(utc='2023-11-28T17:03:42Z', local='2023-11-28T20:03:42+03:00'), datetime_last=Datetime(utc='2025-12-21T04:58:04Z', local='2025-12-21T07:58:04+03:00')),
#  Location(id=2156118, name='Nairobi', locality=None, timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=9, name='Clarity'), provider=ProviderBase(id=166, name='Clarity'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=4, name='Clarity Sensor')], sensors=[SensorBase(id=7765850, name='no2 ppb', parameter=ParameterBase(id=15, name='no2', units='ppb', display_name='NO₂')), SensorBase(id=7765851, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7765852, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7765853, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7765854, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7765855, name='temperature f', parameter=ParameterBase(id=128, name='temperature', units='f', display_name='Temperature (F)'))], coordinates=Coordinates(latitude=-1.33159, longitude=36.91271), bounds=[36.91271, -1.33159, 36.91271, -1.33159], distance=None, datetime_first=Datetime(utc='2024-01-28T15:00:32Z', local='2024-01-28T18:00:32+03:00'), datetime_last=Datetime(utc='2025-10-16T05:47:28Z', local='2025-10-16T08:47:28+03:00')),
#  Location(id=2388059, name='Nyayo Embakasi, Nairobi', locality=None, timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='Unknown AirGradient Sensor'), InstrumentBase(id=7, name='Unknown AirGradient Sensor')], sensors=[SensorBase(id=7970953, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7981687, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7981696, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7971111, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7817013, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7971951, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=7817012, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7971957, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=-1.304011, longitude=36.907681), bounds=[36.907681, -1.304011, 36.907681, -1.304011], distance=None, datetime_first=Datetime(utc='2024-02-06T05:00:00Z', local='2024-02-06T08:00:00+03:00'), datetime_last=Datetime(utc='2024-05-09T18:00:00Z', local='2024-05-09T21:00:00+03:00')),
#  Location(id=3394396, name='Nairobi CMR', locality='N/A', timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=12151945, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=-1.232511, longitude=36.81732), bounds=[36.81732, -1.232511, 36.81732, -1.232511], distance=None, datetime_first=Datetime(utc='2025-02-06T18:00:00Z', local='2025-02-06T21:00:00+03:00'), datetime_last=Datetime(utc='2025-06-26T10:00:00Z', local='2025-06-26T13:00:00+03:00')),
#  Location(id=3394397, name='Nairobi CMR', locality='N/A', timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=12161516, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=-1.232511, longitude=36.81732), bounds=[36.81732, -1.232511, 36.81732, -1.232511], distance=None, datetime_first=Datetime(utc='2025-02-10T22:00:00Z', local='2025-02-11T01:00:00+03:00'), datetime_last=Datetime(utc='2025-02-11T21:00:00Z', local='2025-02-12T00:00:00+03:00')),
#  Location(id=3399524, name='Nairobi RR', locality='N/A', timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=12167724, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=-1.22291, longitude=36.80549), bounds=[36.80549, -1.22291, 36.80549, -1.22291], distance=None, datetime_first=Datetime(utc='2025-02-12T13:00:00Z', local='2025-02-12T16:00:00+03:00'), datetime_last=Datetime(utc='2025-02-17T16:00:00Z', local='2025-02-17T19:00:00+03:00')),
#  Location(id=5119477, name='Kitisuru', locality=None, timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=12, name='AirGradient'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=24, name='AirGradient Open Air Generation 1 (O-1PST)')], sensors=[SensorBase(id=13633454, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=13633455, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=13633456, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=13633457, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=13633458, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=-1.2252518809076456, longitude=36.75807771613854), bounds=[36.75807771613854, -1.2252518809076456, 36.75807771613854, -1.2252518809076456], distance=None, datetime_first=Datetime(utc='2025-07-18T13:00:00Z', local='2025-07-18T16:00:00+03:00'), datetime_last=Datetime(utc='2025-12-09T09:00:00Z', local='2025-12-09T12:00:00+03:00')),
#  Location(id=5199863, name='Kihumo Village || Antenna Array', locality=None, timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=16933, name='The Demography Project'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=24, name='AirGradient Open Air Generation 1 (O-1PST)')], sensors=[SensorBase(id=13691748, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=13691749, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=13691750, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=13691751, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=13691752, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=-1.2618359714875163, longitude=36.686049384630266), bounds=[36.686049384630266, -1.2618359714875163, 36.686049384630266, -1.2618359714875163], distance=None, datetime_first=Datetime(utc='2025-07-25T11:00:00Z', local='2025-07-25T14:00:00+03:00'), datetime_last=Datetime(utc='2025-12-21T05:00:00Z', local='2025-12-21T08:00:00+03:00')),
#  Location(id=5672958, name='KENBIFS01', locality=None, timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=1, name='OpenAQ admin'), provider=ProviderBase(id=12, name='Clean Air Catalyst'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=1, name='N/A'), InstrumentBase(id=12, name='MA350'), InstrumentBase(id=13, name='AIO 2'), InstrumentBase(id=18, name='BAM 1022')], sensors=[SensorBase(id=14341710, name='bc_375 ng/m³', parameter=ParameterBase(id=19861, name='bc_375', units='ng/m³', display_name='BC 375nm')), SensorBase(id=14341711, name='bc_880 ng/m³', parameter=ParameterBase(id=19865, name='bc_880', units='ng/m³', display_name='BC 880nm')), SensorBase(id=14038275, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=14038280, name='pressure hpa', parameter=ParameterBase(id=95, name='pressure', units='hpa', display_name='Atmospheric pressure')), SensorBase(id=14038281, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=14038282, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=14341712, name='wind_direction deg', parameter=ParameterBase(id=22, name='wind_direction', units='deg', display_name='Wind direction')), SensorBase(id=14341713, name='wind_speed m/s', parameter=ParameterBase(id=34, name='wind_speed', units='m/s', display_name='Wind speed'))], coordinates=Coordinates(latitude=-1.2818, longitude=36.8232), bounds=[36.8232, -1.2818, 36.8232, -1.2818], distance=None, datetime_first=Datetime(utc='2024-09-03T14:00:00Z', local='2024-09-03T17:00:00+03:00'), datetime_last=Datetime(utc='2025-05-31T15:00:00Z', local='2025-05-31T18:00:00+03:00')),
#  Location(id=5672959, name='KENBIMLK01', locality=None, timezone='Africa/Nairobi', country=CountryBase(id=17, code='KE', name='Kenya'), owner=OwnerBase(id=1, name='OpenAQ admin'), provider=ProviderBase(id=12, name='Clean Air Catalyst'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=1, name='N/A'), InstrumentBase(id=13, name='AIO 2'), InstrumentBase(id=18, name='BAM 1022')], sensors=[SensorBase(id=14341714, name='bc_375 ng/m³', parameter=ParameterBase(id=19861, name='bc_375', units='ng/m³', display_name='BC 375nm')), SensorBase(id=14341715, name='bc_470 ng/m³', parameter=ParameterBase(id=19862, name='bc_470', units='ng/m³', display_name='BC 470nm')), SensorBase(id=14341716, name='bc_528 ng/m³', parameter=ParameterBase(id=19863, name='bc_528', units='ng/m³', display_name='BC 528nm')), SensorBase(id=14341717, name='bc_625 ng/m³', parameter=ParameterBase(id=19864, name='bc_625', units='ng/m³', display_name='BC 625nm')), SensorBase(id=14341718, name='bc_880 ng/m³', parameter=ParameterBase(id=19865, name='bc_880', units='ng/m³', display_name='BC 880nm')), SensorBase(id=14038279, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=14038276, name='pressure hpa', parameter=ParameterBase(id=95, name='pressure', units='hpa', display_name='Atmospheric pressure')), SensorBase(id=14038277, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=14038278, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=14341719, name='wind_direction deg', parameter=ParameterBase(id=22, name='wind_direction', units='deg', display_name='Wind direction')), SensorBase(id=14341720, name='wind_speed m/s', parameter=ParameterBase(id=34, name='wind_speed', units='m/s', display_name='Wind speed'))], coordinates=Coordinates(latitude=-1.2742, longitude=36.899), bounds=[36.899, -1.2742, 36.899, -1.2742], distance=None, datetime_first=Datetime(utc='2024-09-03T14:00:00Z', local='2024-09-03T17:00:00+03:00'), datetime_last=Datetime(utc='2025-05-31T15:00:00Z', local='2025-05-31T18:00:00+03:00'))]

# %%
#Create a Clean DataFrame of Locations
locs = bbox_locations_search.results

clean_rows = []

for loc in locs:
    clean_rows.append({
        "id": loc.id,
        "name": loc.name,
        "latitude": loc.coordinates.latitude,
        "longitude": loc.coordinates.longitude,
        "provider": loc.provider.name,
        "is_monitor": loc.is_monitor,
        "sensor_count": len(loc.sensors),
        "first_seen": loc.datetime_first.local,
        "last_seen": loc.datetime_last.local
    })

df_locations = pd.DataFrame(clean_rows)
df_locations
# Out:
#          id                             name  latitude  longitude  \
# 0      5994                      Nairobi CBD -1.281560  36.818830
# 1      6317              Alliance Girls High -1.266140  36.663140
# 2    352507                       Nairobi RR -1.234370  36.817320
# 3   1894637                           Nakuru -0.267400  36.021800
# 4   2156118                          Nairobi -1.331590  36.912710
# 5   2388059          Nyayo Embakasi, Nairobi -1.304011  36.907681
# 6   3394396                      Nairobi CMR -1.232511  36.817320
# 7   3394397                      Nairobi CMR -1.232511  36.817320
# 8   3399524                       Nairobi RR -1.222910  36.805490
# 9   5119477                         Kitisuru -1.225252  36.758078
# 10  5199863  Kihumo Village || Antenna Array -1.261836  36.686049
# 11  5672958                        KENBIFS01 -1.281800  36.823200
# 12  5672959                       KENBIMLK01 -1.274200  36.899000
#
#               provider  is_monitor  sensor_count                 first_seen  \
# 0         AirNow Kenya        True             2  2018-04-23T03:00:00+03:00
# 1         AirNow Kenya        True             2  2018-04-21T03:00:00+03:00
# 2               AirNow        True             1  2022-06-16T20:00:00+03:00
# 3              Clarity       False             5  2023-11-28T20:03:42+03:00
# 4              Clarity       False             6  2024-01-28T18:00:32+03:00
# 5          AirGradient       False             8  2024-02-06T08:00:00+03:00
# 6               AirNow        True             1  2025-02-06T21:00:00+03:00
# 7               AirNow        True             1  2025-02-11T01:00:00+03:00
# 8               AirNow        True             1  2025-02-12T16:00:00+03:00
# 9          AirGradient       False             5  2025-07-18T16:00:00+03:00
# 10         AirGradient       False             5  2025-07-25T14:00:00+03:00
# 11  Clean Air Catalyst        True             8  2024-09-03T17:00:00+03:00
# 12  Clean Air Catalyst        True            11  2024-09-03T17:00:00+03:00
#
#                     last_seen
# 0   2018-09-14T00:00:00+03:00
# 1   2018-11-21T02:00:00+03:00
# 2   2025-02-12T18:00:00+03:00
# 3   2025-12-21T07:58:04+03:00
# 4   2025-10-16T08:47:28+03:00
# 5   2024-05-09T21:00:00+03:00
# 6   2025-06-26T13:00:00+03:00
# 7   2025-02-12T00:00:00+03:00
# 8   2025-02-17T19:00:00+03:00
# 9   2025-12-09T12:00:00+03:00
# 10  2025-12-21T08:00:00+03:00
# 11  2025-05-31T18:00:00+03:00
# 12  2025-05-31T18:00:00+03:00

# %%
#Sort all locations by their most recent reading timestamp
df_locations['first_seen'] = pd.to_datetime(df_locations['first_seen'])
df_locations['last_seen'] = pd.to_datetime(df_locations['last_seen'])
df_locations = df_locations.sort_values(by='last_seen', ascending=False)
df_locations
# Out:
#          id                             name  latitude  longitude  \
# 10  5199863  Kihumo Village || Antenna Array -1.261836  36.686049
# 3   1894637                           Nakuru -0.267400  36.021800
# 9   5119477                         Kitisuru -1.225252  36.758078
# 4   2156118                          Nairobi -1.331590  36.912710
# 6   3394396                      Nairobi CMR -1.232511  36.817320
# 11  5672958                        KENBIFS01 -1.281800  36.823200
# 12  5672959                       KENBIMLK01 -1.274200  36.899000
# 8   3399524                       Nairobi RR -1.222910  36.805490
# 2    352507                       Nairobi RR -1.234370  36.817320
# 7   3394397                      Nairobi CMR -1.232511  36.817320
# 5   2388059          Nyayo Embakasi, Nairobi -1.304011  36.907681
# 1      6317              Alliance Girls High -1.266140  36.663140
# 0      5994                      Nairobi CBD -1.281560  36.818830
#
#               provider  is_monitor  sensor_count                first_seen  \
# 10         AirGradient       False             5 2025-07-25 14:00:00+03:00
# 3              Clarity       False             5 2023-11-28 20:03:42+03:00
# 9          AirGradient       False             5 2025-07-18 16:00:00+03:00
# 4              Clarity       False             6 2024-01-28 18:00:32+03:00
# 6               AirNow        True             1 2025-02-06 21:00:00+03:00
# 11  Clean Air Catalyst        True             8 2024-09-03 17:00:00+03:00
# 12  Clean Air Catalyst        True            11 2024-09-03 17:00:00+03:00
# 8               AirNow        True             1 2025-02-12 16:00:00+03:00
# 2               AirNow        True             1 2022-06-16 20:00:00+03:00
# 7               AirNow        True             1 2025-02-11 01:00:00+03:00
# 5          AirGradient       False             8 2024-02-06 08:00:00+03:00
# 1         AirNow Kenya        True             2 2018-04-21 03:00:00+03:00
# 0         AirNow Kenya        True             2 2018-04-23 03:00:00+03:00
#
#                    last_seen
# 10 2025-12-21 08:00:00+03:00
# 3  2025-12-21 07:58:04+03:00
# 9  2025-12-09 12:00:00+03:00
# 4  2025-10-16 08:47:28+03:00
# 6  2025-06-26 13:00:00+03:00
# 11 2025-05-31 18:00:00+03:00
# 12 2025-05-31 18:00:00+03:00
# 8  2025-02-17 19:00:00+03:00
# 2  2025-02-12 18:00:00+03:00
# 7  2025-02-12 00:00:00+03:00
# 5  2024-05-09 21:00:00+03:00
# 1  2018-11-21 02:00:00+03:00
# 0  2018-09-14 00:00:00+03:00

# %%
#Create a dictionary for mapping each location ID to its location name.
locations_info = {}

for location in bbox_locations_search.results:
    locations_info[location.id] = location.name

locations_info
# Out:
# {5994: 'Nairobi CBD',
#  6317: 'Alliance Girls High',
#  352507: 'Nairobi RR',
#  1894637: 'Nakuru',
#  2156118: 'Nairobi',
#  2388059: 'Nyayo Embakasi, Nairobi',
#  3394396: 'Nairobi CMR',
#  3394397: 'Nairobi CMR',
#  3399524: 'Nairobi RR',
#  5119477: 'Kitisuru',
#  5199863: 'Kihumo Village || Antenna Array',
#  5672958: 'KENBIFS01',
#  5672959: 'KENBIMLK01'}

# %%
#Look at location 'nakuru' data
bbox_locations_search.results[3].__dict__
# Out:
# {'id': 1894637,
#  'name': 'Nakuru',
#  'locality': None,
#  'timezone': 'Africa/Nairobi',
#  'country': CountryBase(id=17, code='KE', name='Kenya'),
#  'owner': OwnerBase(id=9, name='Clarity'),
#  'provider': ProviderBase(id=166, name='Clarity'),
#  'is_mobile': False,
#  'is_monitor': False,
#  'instruments': [InstrumentBase(id=4, name='Clarity Sensor')],
#  'sensors': [SensorBase(id=7466383, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')),
#   SensorBase(id=7466384, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')),
#   SensorBase(id=7466385, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')),
#   SensorBase(id=7466386, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')),
#   SensorBase(id=7466387, name='temperature f', parameter=ParameterBase(id=128, name='temperature', units='f', display_name='Temperature (F)'))],
#  'coordinates': Coordinates(latitude=-0.2674, longitude=36.0218),
#  'bounds': [36.0218, -0.2674, 36.0218, -0.2674],
#  'distance': None,
#  'datetime_first': Datetime(utc='2023-11-28T17:03:42Z', local='2023-11-28T20:03:42+03:00'),
#  'datetime_last': Datetime(utc='2025-12-21T04:58:04Z', local='2025-12-21T07:58:04+03:00')}

# %%
#Save locations_info as a JSON file
with open(r"..\locations.json", "w") as f:
    json.dump(locations_info, f, indent=4, sort_keys=True)
